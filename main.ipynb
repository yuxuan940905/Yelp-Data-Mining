# %%
# %run clustering/main.py
# Out:
# Querying https://api.yelp.com/v3/businesses/search ...
# 825 businesses for pizza in Boston of price level $
# Querying https://api.yelp.com/v3/businesses/search ...
# 825 businesses for pizza in Boston of price level $
# Querying https://api.yelp.com/v3/businesses/search ...
# 825 businesses for pizza in Boston of price level $
# Querying https://api.yelp.com/v3/businesses/search ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Desktop/yelp data mining final project/clustering/main.py in <module>()
#      60
#      61 if __name__ == '__main__':
# ---> 62     main()
#
# ~/Desktop/yelp data mining final project/clustering/main.py in main()
#      22
#      23     Location=[]
# ---> 24     Location,ratings,idList,priceList=search.searchWithOffset(20)
#      25     kmeans = KMeans(n_clusters=5, random_state=0).fit(Location)
# ...

# %%
# %run LDA/wordclouds.py
